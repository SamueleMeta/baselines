# %% [markdown]
# # PB-POMIS, batchsize = 1

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
import glob
from importlib import reload
reload(nu)
# Out:
# <module 'baselines.common.notebook_utils' from '/home/matteo/baselines/baselines/common/notebook_utils.py'>

# %%
plt.close('all')

# %%
seeds = [10, 109, 904, 160, 570]

# %%
path = '../results/pbpomis_one/'

# %% [markdown]
# ## Setting:
# * Batchsize = 1
# * No bias
# * No centering

# %% [markdown]
# ****

# %% [markdown]
# ## - Tuning -

# %%
deltas = [0.8, 0.6, 0.4, 0.2, 0.1, 0.05, 0.01, 0.005, 0.001]

# %% [markdown]
# ## Cartpole

# %% [markdown]
# ### Single IS (capacity = 1) (cannot be normalized)

# %%
files = {delta : glob.glob(path + '*env=RLLAB.CARTPOLE*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_IS = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_IS, bootstrap=True, roll=10)
# Out:
# delta=0.8000: 80.115728 ± 15.737127	[60.575504, 99.655953]	 total horizon: 90124
# delta=0.6000: 94.718338 ± 69.130533	[8.881444, 180.555231]	 total horizon: 104731
# delta=0.4000: 80.412635 ± 29.497284	[43.786920, 117.038351]	 total horizon: 87038
# delta=0.2000: 107.870985 ± 36.225471	[62.891122, 152.850848]	 total horizon: 117886
# delta=0.1000: 71.000690 ± 10.341068	[58.160559, 83.840822]	 total horizon: 81000
# delta=0.0500: 70.651169 ± 22.170054	[43.123411, 98.178926]	 total horizon: 73558
# delta=0.0100: 84.692140 ± 27.606552	[50.414078, 118.970202]	 total horizon: 94697
# delta=0.0050: 87.201379 ± 21.914867	[59.990477, 114.412281]	 total horizon: 97208
# delta=0.0010: 105.031523 ± 9.013398	[93.839912, 116.223134]	 total horizon: 115045

# %% [markdown]
# ### MULTIPLE IS (capacity = 10), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.CARTPOLE*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS10 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS10, bootstrap=True, roll=10)
# Out:
# delta=0.8000: 1344.627859 ± 2039.638763	[-1187.918162, 3877.173880]	 total horizon: 1352784
# delta=0.6000: 711.865857 ± 393.193053	[223.652199, 1200.079515]	 total horizon: 722007
# delta=0.4000: 687.213142 ± 826.906874	[-339.527354, 1713.953638]	 total horizon: 697299
# delta=0.2000: 2343.556803 ± 2444.602860	[-691.818559, 5378.932164]	 total horizon: 2349744
# delta=0.1000: 732.414022 ± 546.471922	[53.879511, 1410.948533]	 total horizon: 742605
# delta=0.0500: 3209.733480 ± 1798.735438	[976.308445, 5443.158516]	 total horizon: 3215837
# delta=0.0100: 1707.789778 ± 1804.942765	[-533.342673, 3948.922228]	 total horizon: 1716064
# delta=0.0050: 2675.682211 ± 1742.107547	[512.569988, 4838.794434]	 total horizon: 2683759
# delta=0.0010: 3543.525945 ± 1338.274225	[1881.839020, 5205.212869]	 total horizon: 3549439

# %% [markdown]
# ### MULTIPLE IS (capacity = 10), unnormalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.CARTPOLE*norm=none*batchsize=1_*cap=10_*delta=%.4f*' % delta) for delta in deltas}
candidates_UNN10 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_UNN10, bootstrap=True, roll=10)
# Out:
# delta=0.8000: 586.337153 ± 506.729119	[-42.850151, 1215.524457]	 total horizon: 596507
# delta=0.6000: 612.400288 ± 368.687035	[154.614870, 1070.185706]	 total horizon: 622568
# delta=0.4000: 874.856736 ± 893.824917	[-234.973484, 1984.686956]	 total horizon: 884788
# delta=0.2000: 589.248606 ± 633.432317	[-197.261497, 1375.758709]	 total horizon: 599393
# delta=0.1000: 2144.984917 ± 2444.372962	[-890.104988, 5180.074822]	 total horizon: 2151297
# delta=0.0500: 1030.491441 ± 856.824099	[-33.396195, 2094.379078]	 total horizon: 1040663
# delta=0.0100: 2330.095657 ± 1904.462518	[-34.606888, 4694.798202]	 total horizon: 2336861
# delta=0.0050: 1520.850652 ± 1211.921927	[16.050827, 3025.650477]	 total horizon: 1529648
# delta=0.0010: 1219.832420 ± 1773.849001	[-982.692023, 3422.356864]	 total horizon: 1228127

# %% [markdown]
# ### MULTIPLE IS (capacity = 50), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.CARTPOLE*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS50 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS50, bootstrap=True, roll=10)
# Out:
# delta=0.8000: 1233.004174 ± 2094.151176	[-1367.227948, 3833.236296]	 total horizon: 1241179
# delta=0.6000: 670.563374 ± 296.323073	[302.629682, 1038.497066]	 total horizon: 680732
# delta=0.4000: 617.869837 ± 831.273651	[-414.292728, 1650.032402]	 total horizon: 627916
# delta=0.2000: 1810.161208 ± 1830.236353	[-462.377379, 4082.699796]	 total horizon: 1818294
# delta=0.1000: 2086.598550 ± 1938.252482	[-320.059776, 4493.256876]	 total horizon: 2659536
# delta=0.0500: 1717.641816 ± 1971.643538	[-730.476982, 4165.760614]	 total horizon: 1725808
# delta=0.0100: 3073.012312 ± 1903.460483	[709.553958, 5436.470666]	 total horizon: 3079133
# delta=0.0050: 3526.806187 ± 2031.518460	[1004.342853, 6049.269521]	 total horizon: 3531049
# delta=0.0010: 4742.520902 ± 128.245960	[4583.282510, 4901.759294]	 total horizon: 4743585

# %% [markdown]
# ### MULTIPLE IS (capacity = 50), unnormalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.CARTPOLE*norm=none*batchsize=1_*cap=50_*delta=%.4f*' % delta) for delta in deltas}
candidates_UNN50 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_UNN50, bootstrap=True, roll=10)
# Out:
# delta=0.8000: 2412.936935 ± 1997.417846	[-67.184894, 4893.058764]	 total horizon: 2419742
# delta=0.6000: 1611.639600 ± 1775.138804	[-592.486344, 3815.765544]	 total horizon: 1620064
# delta=0.4000: 1654.406175 ± 1705.522223	[-463.279368, 3772.091717]	 total horizon: 1662920
# delta=0.2000: 3054.060042 ± 1926.791493	[661.632413, 5446.487671]	 total horizon: 3059639
# delta=0.1000: 2144.602288 ± 1366.062046	[448.412226, 3840.792350]	 total horizon: 2152856
# delta=0.0500: 2593.789413 ± 1649.856080	[545.222516, 4642.356311]	 total horizon: 2600584
# delta=0.0100: 2247.609750 ± 1365.248478	[552.429866, 3942.789633]	 total horizon: 2254833
# delta=0.0050: 2256.889358 ± 1793.162449	[30.384102, 4483.394614]	 total horizon: 2263090
# delta=0.0010: 353.862550 ± 440.201808	[-192.720187, 900.445286]	 total horizon: 363930

# %% [markdown]
# ### SINGLE vs MULTI (best delta, normalize when possible)

# %%
f = nu.compare({'single (delta = 0.2)' : candidates_IS['delta=0.2000'], 
                'multi (capacity=10, delta = 0.001)': candidates_MIS10['delta=0.0010'],
               'multi (capacity=50, delta = 0.001)': candidates_MIS50['delta=0.0010']},
              bootstrap=True, roll=10)
# Out:
# single (delta = 0.2): 107.870985 ± 36.225471	[62.891122, 152.850848]	 total horizon: 117886
# multi (capacity=10, delta = 0.001): 3543.525945 ± 1338.274225	[1881.839020, 5205.212869]	 total horizon: 3549439
# multi (capacity=50, delta = 0.001): 4742.520902 ± 128.245960	[4583.282510, 4901.759294]	 total horizon: 4743585

# %% [markdown]
# ### Single with batchsize = 10

# %%
files = {delta : glob.glob(path + '*env=RLLAB.CARTPOLE*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_BATCH = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_BATCH, bootstrap=True)
# Out:
# delta=0.8000: 1827.809521 ± 1901.479595	[-533.189235, 4188.808278]	 total horizon: 183605
# delta=0.6000: 2698.799900 ± 1702.728106	[584.583712, 4813.016088]	 total horizon: 270671
# delta=0.4000: 2173.947909 ± 1629.396982	[150.784337, 4197.111480]	 total horizon: 218228
# delta=0.2000: 2878.235323 ± 1208.857351	[1377.240672, 4379.229975]	 total horizon: 288677
# delta=0.1000: 4888.405683 ± 37.612640	[4841.703422, 4935.107944]	 total horizon: 488898
# delta=0.0500: 4831.386645 ± 45.926837	[4774.360945, 4888.412346]	 total horizon: 483193
# delta=0.0100: 4639.614744 ± 12.596776	[4623.973781, 4655.255707]	 total horizon: 464054
# delta=0.0050: 4486.857478 ± 81.736260	[4385.368507, 4588.346450]	 total horizon: 448814
# delta=0.0010: 3816.094099 ± 92.957131	[3700.672577, 3931.515622]	 total horizon: 381900

# %% [markdown]
# ### 1 x 10 vs 10 x 1

# %%
f = nu.compare({'batchsize=1, capacity=10 (delta = 0.001)': candidates_MIS10['delta=0.0010'],
               'batchsize=10, capacity=1 (delta = 0.1)': candidates_BATCH['delta=0.1000']},
              bootstrap=True, roll=[10, 1])
# Out:
# batchsize=1, capacity=10 (delta = 0.001): 3543.525945 ± 1338.274225	[1881.839020, 5205.212869]	 total horizon: 3549439
# batchsize=10, capacity=1 (delta = 0.1): 4888.405683 ± 37.612640	[4841.703422, 4935.107944]	 total horizon: 488898

# %% [markdown]
# ****

# %% [markdown]
# ## Mountain Car

# %% [markdown]
# ### Single IS (capacity = 1) (cannot be normalized)

# %%
files = {delta : glob.glob(path + '*env=RLLAB.MOUNTAIN-CAR*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_IS = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_IS, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -151.009405 ± 148.441509	[-335.323883, 33.305073]	 total horizon: 1945225
# delta=0.6000: -98.881382 ± 6.839667	[-107.373950, -90.388814]	 total horizon: 1354203
# delta=0.4000: -105.868916 ± 8.494149	[-116.415795, -95.322036]	 total horizon: 1436856
# delta=0.2000: -124.320092 ± 7.539918	[-133.682137, -114.958048]	 total horizon: 1654475
# delta=0.1000: -141.863643 ± 4.901438	[-147.949582, -135.777704]	 total horizon: 1866249
# delta=0.0500: -166.396097 ± 4.785823	[-172.338482, -160.453713]	 total horizon: 2153633
# delta=0.0100: -222.146830 ± 6.395612	[-230.088031, -214.205629]	 total horizon: 2801832
# delta=0.0050: -250.034129 ± 4.510205	[-255.634288, -244.433970]	 total horizon: 3125357
# delta=0.0010: -288.101549 ± 3.972557	[-293.034129, -283.168968]	 total horizon: 3561403

# %% [markdown]
# ### MULTIPLE IS (capacity = 10), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.MOUNTAIN-CAR*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS10 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS10, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -213.063455 ± 126.757481	[-370.453657, -55.673254]	 total horizon: 2722222
# delta=0.6000: -112.760047 ± 24.001802	[-142.562220, -82.957874]	 total horizon: 1526059
# delta=0.4000: -105.183591 ± 16.809626	[-126.055499, -84.311684]	 total horizon: 1426010
# delta=0.2000: -101.547703 ± 18.433211	[-124.435558, -78.659848]	 total horizon: 1380254
# delta=0.1000: -104.333867 ± 10.033362	[-116.791931, -91.875803]	 total horizon: 1418770
# delta=0.0500: -97.353110 ± 10.117563	[-109.915723, -84.790496]	 total horizon: 1326986
# delta=0.0100: -89.026996 ± 6.684525	[-97.326930, -80.727062]	 total horizon: 1224484
# delta=0.0050: -85.397315 ± 5.414219	[-92.119956, -78.674673]	 total horizon: 1178260
# delta=0.0010: -79.737155 ± 5.878340	[-87.036078, -72.438232]	 total horizon: 1109194

# %% [markdown]
# ### MULTIPLE IS (capacity = 50), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.MOUNTAIN-CAR*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS50 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS50, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -256.936255 ± 152.085580	[-445.775445, -68.097065]	 total horizon: 3200825
# delta=0.6000: -165.254765 ± 141.379384	[-340.800457, 10.290927]	 total horizon: 2111982
# delta=0.4000: -108.661203 ± 13.438592	[-125.347420, -91.974987]	 total horizon: 1473781
# delta=0.2000: -166.935720 ± 140.319497	[-341.165388, 7.293948]	 total horizon: 2134643
# delta=0.1000: -156.164598 ± 145.623930	[-336.980589, 24.651393]	 total horizon: 1998206
# delta=0.0500: -105.792129 ± 24.032790	[-135.632779, -75.951479]	 total horizon: 1431486
# delta=0.0100: -89.083641 ± 6.411155	[-97.044141, -81.123141]	 total horizon: 1224909
# delta=0.0050: -85.665945 ± 4.983026	[-91.853188, -79.478702]	 total horizon: 1181658
# delta=0.0010: -85.309313 ± 3.797334	[-90.024326, -80.594300]	 total horizon: 1176779

# %% [markdown]
# ### SINGLE vs MULTI

# %%
f = nu.compare({'single (delta = 0.6)' : candidates_IS['delta=0.6000'], 
                'multi (capacity=10, delta = 0.001)': candidates_MIS10['delta=0.0010'], 
                'multi (capacity=50, delta = 0.001)': candidates_MIS50['delta=0.0010']},
              bootstrap=True, roll=10)
# Out:
# single (delta = 0.6): -98.881382 ± 6.839667	[-107.373950, -90.388814]	 total horizon: 1354203
# multi (capacity=10, delta = 0.001): -79.737155 ± 5.878340	[-87.036078, -72.438232]	 total horizon: 1109194
# multi (capacity=50, delta = 0.001): -85.309313 ± 3.797334	[-90.024326, -80.594300]	 total horizon: 1176779

# %% [markdown]
# ### Single with batchsize = 10

# %%
files = {delta : glob.glob(path + '*env=RLLAB.MOUNTAIN-CAR*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_BATCH = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_BATCH, bootstrap=True)
# Out:
# delta=0.8000: -92.098865 ± 4.558367	[-97.758825, -86.438905]	 total horizon: 126358
# delta=0.6000: -92.260691 ± 8.117223	[-102.339555, -82.181827]	 total horizon: 126574
# delta=0.4000: -89.372496 ± 4.980284	[-95.556336, -83.188656]	 total horizon: 122942
# delta=0.2000: -84.725259 ± 3.721041	[-89.345541, -80.104977]	 total horizon: 117394
# delta=0.1000: -80.130908 ± 2.636270	[-83.404269, -76.857546]	 total horizon: 111716
# delta=0.0500: -76.844532 ± 3.120042	[-80.718576, -72.970489]	 total horizon: 107600
# delta=0.0100: -76.980378 ± 2.024529	[-79.494163, -74.466592]	 total horizon: 107876
# delta=0.0050: -80.383816 ± 1.724434	[-82.524984, -78.242649]	 total horizon: 111863
# delta=0.0010: -87.323275 ± 0.724537	[-88.222906, -86.423644]	 total horizon: 120321

# %% [markdown]
# ### 1 x 10 vs 10 x 1

# %%
f = nu.compare({'batchsize=1, capacity=10 (delta = 0.001)': candidates_MIS10['delta=0.0010'],
               'batchsize=10, capacity=1 (delta = 0.05)': candidates_BATCH['delta=0.0500']},
              bootstrap=True, roll=[10, 1])
# Out:
# batchsize=1, capacity=10 (delta = 0.001): -79.737155 ± 5.878340	[-87.036078, -72.438232]	 total horizon: 1109194
# batchsize=10, capacity=1 (delta = 0.05): -76.844532 ± 3.120042	[-80.718576, -72.970489]	 total horizon: 107600

# %% [markdown]
# ****

# %% [markdown]
# ## Inverted Pendulum

# %% [markdown]
# ### Single IS (capacity = 1) (cannot be normalized)

# %%
files = {delta : glob.glob(path + '*env=RLLAB.INVERTED-PENDULUM*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_IS = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_IS, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -119.716018 ± 0.701289	[-120.586784, -118.845253]	 total horizon: 364296
# delta=0.6000: -123.826783 ± 4.321017	[-129.192034, -118.461531]	 total horizon: 446174
# delta=0.4000: -122.371484 ± 0.617482	[-123.138188, -121.604779]	 total horizon: 420661
# delta=0.2000: -125.048001 ± 3.638852	[-129.566233, -120.529769]	 total horizon: 462737
# delta=0.1000: -124.929444 ± 0.961332	[-126.123096, -123.735792]	 total horizon: 460491
# delta=0.0500: -125.957798 ± 0.444024	[-126.509126, -125.406469]	 total horizon: 475115
# delta=0.0100: -127.870351 ± 0.170521	[-128.082081, -127.658621]	 total horizon: 505898
# delta=0.0050: -128.136808 ± 0.801069	[-129.131467, -127.142150]	 total horizon: 509950
# delta=0.0010: -128.342515 ± 0.572381	[-129.053220, -127.631810]	 total horizon: 509342

# %% [markdown]
# ### MULTIPLE IS (capacity = 10), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.INVERTED-PENDULUM*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS10 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS10, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -103.856150 ± 4.009886	[-108.835081, -98.877218]	 total horizon: 323506
# delta=0.6000: -106.641711 ± 0.022378	[-106.669497, -106.613925]	 total horizon: 165806
# delta=0.4000: -101.941247 ± 4.789357	[-107.888018, -95.994475]	 total horizon: 346069
# delta=0.2000: -81.472880 ± 26.383154	[-114.231892, -48.713868]	 total horizon: 1388399
# delta=0.1000: -100.237444 ± 11.148429	[-114.080047, -86.394840]	 total horizon: 380147
# delta=0.0500: -104.717160 ± 2.386643	[-107.680569, -101.753752]	 total horizon: 252782
# delta=0.0100: -101.184081 ± 13.406329	[-117.830237, -84.537924]	 total horizon: 386702
# delta=0.0050: -107.447717 ± 0.092918	[-107.563090, -107.332344]	 total horizon: 172499
# delta=0.0010: -108.061041 ± 0.031873	[-108.100617, -108.021465]	 total horizon: 175401

# %% [markdown]
# ### MULTIPLE IS (capacity = 50), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.INVERTED-PENDULUM*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS50 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS50, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -106.075462 ± 1.858169	[-108.382684, -103.768240]	 total horizon: 244302
# delta=0.6000: -99.054058 ± 12.647226	[-114.757662, -83.350453]	 total horizon: 478586
# delta=0.4000: -102.142729 ± 6.386748	[-110.072924, -94.212534]	 total horizon: 462092
# delta=0.2000: -92.113707 ± 26.414856	[-124.912082, -59.315331]	 total horizon: 646390
# delta=0.1000: -88.303149 ± 26.846219	[-121.637132, -54.969165]	 total horizon: 775321
# delta=0.0500: -106.935981 ± 0.658947	[-107.754171, -106.117791]	 total horizon: 188747
# delta=0.0100: -107.494365 ± 0.281090	[-107.843384, -107.145345]	 total horizon: 178365
# delta=0.0050: -107.814417 ± 0.209524	[-108.074575, -107.554259]	 total horizon: 173655
# delta=0.0010: -108.703672 ± 0.144555	[-108.883161, -108.524183]	 total horizon: 184690

# %% [markdown]
# ### SINGLE vs MULTI

# %%
f = nu.compare({'single (delta = 0.8)' : candidates_IS['delta=0.8000'], 
                'multi (capacity=10, delta = 0.2)': candidates_MIS10['delta=0.2000'], 
                'multi (capacity=50, delta = 0.1)': candidates_MIS50['delta=0.1000']},
              bootstrap=True, roll=10)
# Out:
# single (delta = 0.8): -119.716018 ± 0.701289	[-120.586784, -118.845253]	 total horizon: 364296
# multi (capacity=10, delta = 0.2): -81.472880 ± 26.383154	[-114.231892, -48.713868]	 total horizon: 1388399
# multi (capacity=50, delta = 0.1): -88.303149 ± 26.846219	[-121.637132, -54.969165]	 total horizon: 775321

# %% [markdown]
# ### Single with batchsize = 10

# %%
files = {delta : glob.glob(path + '*env=RLLAB.INVERTED-PENDULUM*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_BATCH = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_BATCH, bootstrap=True)
# Out:
# delta=0.8000: -103.432481 ± 4.232776	[-108.688167, -98.176794]	 total horizon: 33602
# delta=0.6000: -96.576917 ± 15.933927	[-116.361500, -76.792333]	 total horizon: 49526
# delta=0.4000: -69.549773 ± 78.552755	[-167.085901, 27.986355]	 total horizon: 108306
# delta=0.2000: -88.070779 ± 18.199617	[-107.170106, -68.971452]	 total horizon: 68345
# delta=0.1000: -55.930961 ± 41.481861	[-107.437495, -4.424428]	 total horizon: 152981
# delta=0.0500: -92.102200 ± 31.581335	[-131.315608, -52.888793]	 total horizon: 61671
# delta=0.0100: -108.086071 ± 0.073519	[-108.177357, -107.994785]	 total horizon: 18690
# delta=0.0050: -108.475676 ± 0.345608	[-108.904805, -108.046547]	 total horizon: 19355
# delta=0.0010: -110.063083 ± 0.128038	[-110.222064, -109.904103]	 total horizon: 21298

# %% [markdown]
# ### 1 x 10 vs 10 x 1

# %%
f = nu.compare({'batchsize=1, capacity=10 (delta = 0.2)': candidates_MIS10['delta=0.2000'],
               'batchsize=10, capacity=1 (delta = 0.1)': candidates_BATCH['delta=0.1000']},
              bootstrap=True, roll=[10, 1])
# Out:
# batchsize=1, capacity=10 (delta = 0.2): -81.472880 ± 26.383154	[-114.231892, -48.713868]	 total horizon: 1388399
# batchsize=10, capacity=1 (delta = 0.1): -55.930961 ± 41.481861	[-107.437495, -4.424428]	 total horizon: 152981

# %% [markdown]
# ****

# %% [markdown]
# ## Double Inverted Pendulum

# %% [markdown]
# ### Single IS (capacity = 1) (cannot be normalized)

# %%
files = {delta : glob.glob(path + '*env=RLLAB.INVERTED-DOUBLE-PENDULUM*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_IS = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_IS, bootstrap=True, roll=10)
# Out:
# delta=0.8000: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# delta=0.6000: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# delta=0.4000: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# delta=0.2000: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# delta=0.1000: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# delta=0.0500: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# delta=0.0100: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# delta=0.0050: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# delta=0.0010: 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380

# %% [markdown]
# ### MULTIPLE IS (capacity = 10), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.INVERTED-DOUBLE-PENDULUM*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS10 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS10, bootstrap=True, roll=10)
# Out:
# delta=0.8000: 427.671555 ± 91.987357	[313.454166, 541.888944]	 total horizon: 461607
# delta=0.6000: 472.442102 ± 160.454457	[273.211580, 671.672625]	 total horizon: 509201
# delta=0.4000: 903.707454 ± 861.711040	[-166.248121, 1973.663029]	 total horizon: 975718
# delta=0.2000: 460.947161 ± 46.692684	[402.970536, 518.923785]	 total horizon: 496693
# delta=0.1000: 449.367356 ± 77.681288	[352.913297, 545.821415]	 total horizon: 484566
# delta=0.0500: 739.275217 ± 307.106209	[357.952494, 1120.597941]	 total horizon: 799082
# delta=0.0100: 1568.751027 ± 1918.243418	[-1483.602312, 4621.104367]	 total horizon: 1694900
# delta=0.0050: 1307.190775 ± 959.113016	[116.294674, 2498.086877]	 total horizon: 1419052
# delta=0.0010: 2517.228097 ± 1161.317159	[1075.262391, 3959.193804]	 total horizon: 2718198

# %% [markdown]
# ### MULTIPLE IS (capacity = 50), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.INVERTED-DOUBLE-PENDULUM*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS50 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS50, bootstrap=True, roll=10)
# Out:
# delta=0.8000: 530.620337 ± 79.741547	[431.608128, 629.632545]	 total horizon: 573048
# delta=0.6000: 517.608546 ± 212.157234	[254.180547, 781.036545]	 total horizon: 557691
# delta=0.4000: 390.019321 ± 63.704504	[310.919732, 469.118909]	 total horizon: 420697
# delta=0.2000: 600.584625 ± 415.849299	[84.239522, 1116.929728]	 total horizon: 647071
# delta=0.1000: 451.364507 ± 129.778452	[290.223275, 612.505739]	 total horizon: 486942
# delta=0.0500: 1089.511371 ± 655.624500	[275.446033, 1903.576710]	 total horizon: 1176510
# delta=0.0100: 1913.248944 ± 1003.966230	[666.660221, 3159.837667]	 total horizon: 2076192
# delta=0.0050: 1072.675314 ± 309.712097	[688.116953, 1457.233675]	 total horizon: 1164330
# delta=0.0010: 2010.271621 ± 791.786229	[1027.139166, 2993.404076]	 total horizon: 2169280

# %% [markdown]
# ### SINGLE vs MULTI

# %%
f = nu.compare({'single (delta = 0.001)' : candidates_IS['delta=0.0010'], 
                'multi (capacity=10, delta = 0.001)': candidates_MIS10['delta=0.0010'], 
                'multi (capacity=50, delta = 0.001)': candidates_MIS50['delta=0.0010']},
              bootstrap=True, roll=10)
# Out:
# single (delta = 0.001): 144.150909 ± 1.879298	[141.817453, 146.484366]	 total horizon: 157380
# multi (capacity=10, delta = 0.001): 2517.228097 ± 1161.317159	[1075.262391, 3959.193804]	 total horizon: 2718198
# multi (capacity=50, delta = 0.001): 2010.271621 ± 791.786229	[1027.139166, 2993.404076]	 total horizon: 2169280

# %% [markdown]
# ### Single with batchsize = 10

# %%
files = {delta : glob.glob(path + '*env=RLLAB.INVERTED-DOUBLE-PENDULUM*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_BATCH = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_BATCH, bootstrap=True)
# Out:
# delta=0.8000: 1686.438876 ± 1815.036085	[-567.226086, 3940.103838]	 total horizon: 181798
# delta=0.6000: 781.372638 ± 409.234411	[273.241003, 1289.504273]	 total horizon: 84489
# delta=0.4000: 641.891374 ± 281.017763	[292.961735, 990.821014]	 total horizon: 69361
# delta=0.2000: 754.916942 ± 399.566373	[258.789762, 1251.044121]	 total horizon: 81912
# delta=0.1000: 1593.691510 ± 1563.800610	[-348.023408, 3535.406429]	 total horizon: 171780
# delta=0.0500: 2547.057354 ± 1559.585154	[610.576617, 4483.538092]	 total horizon: 274753
# delta=0.0100: 917.368521 ± 231.124621	[630.389400, 1204.347642]	 total horizon: 99413
# delta=0.0050: 1580.030826 ± 637.215403	[788.823401, 2371.238250]	 total horizon: 170672
# delta=0.0010: 451.533949 ± 53.193358	[395.710943, 507.356954]	 total horizon: 48772

# %% [markdown]
# ### 1 x 10 vs 10 x 1

# %%
f = nu.compare({'batchsize=1, capacity=10 (delta = 0.001)': candidates_MIS10['delta=0.0010'],
               'batchsize=10, capacity=1 (delta = 0.05)': candidates_BATCH['delta=0.0500']},
              bootstrap=True, roll=[10, 1])
# Out:
# batchsize=1, capacity=10 (delta = 0.001): 2517.228097 ± 1161.317159	[1075.262391, 3959.193804]	 total horizon: 2718198
# batchsize=10, capacity=1 (delta = 0.05): 2547.057354 ± 1559.585154	[610.576617, 4483.538092]	 total horizon: 274753

# %% [markdown]
# ****

# %% [markdown]
# ## Acrobot

# %% [markdown]
# ### Single IS (capacity = 1) (cannot be normalized)

# %%
files = {delta : glob.glob(path + '*env=RLLAB.ACROBOT*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_IS = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_IS, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -1433.791398 ± 6.429516	[-1441.774696, -1425.808100]	 total horizon: 4995500
# delta=0.6000: -1432.097278 ± 4.880514	[-1438.157237, -1426.037319]	 total horizon: 4995500
# delta=0.4000: -1437.905003 ± 4.974890	[-1444.082145, -1431.727861]	 total horizon: 4995500
# delta=0.2000: -1439.399974 ± 2.957287	[-1443.071930, -1435.728017]	 total horizon: 4995500
# delta=0.1000: -1437.279286 ± 2.503925	[-1440.388320, -1434.170252]	 total horizon: 4995500
# delta=0.0500: -1446.678100 ± 3.062445	[-1450.480627, -1442.875573]	 total horizon: 4995500
# delta=0.0100: -1444.410713 ± 3.048691	[-1448.196163, -1440.625264]	 total horizon: 4995500
# delta=0.0050: -1445.648691 ± 3.177028	[-1449.593492, -1441.703889]	 total horizon: 4995500
# delta=0.0010: -1445.544790 ± 3.618807	[-1450.038133, -1441.051448]	 total horizon: 4995500

# %% [markdown]
# ### MULTIPLE IS (capacity = 10), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.ACROBOT*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS10 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS10, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -871.723639 ± 271.613436	[-1208.976263, -534.471014]	 total horizon: 4995500
# delta=0.6000: -688.652348 ± 291.633683	[-1050.763393, -326.541303]	 total horizon: 4995500
# delta=0.4000: -756.962704 ± 350.311043	[-1191.931314, -321.994093]	 total horizon: 4995500
# delta=0.2000: -827.887713 ± 285.158056	[-1181.958204, -473.817221]	 total horizon: 4995500
# delta=0.1000: -832.658532 ± 292.776240	[-1196.188248, -469.128816]	 total horizon: 4995500
# delta=0.0500: -1033.750054 ± 226.931796	[-1315.523095, -751.977014]	 total horizon: 4995500
# delta=0.0100: -668.036356 ± 66.810392	[-750.992414, -585.080297]	 total horizon: 4995500
# delta=0.0050: -892.471128 ± 248.509692	[-1201.036665, -583.905590]	 total horizon: 4995500
# delta=0.0010: -1018.688928 ± 121.830689	[-1169.961708, -867.416148]	 total horizon: 4995500

# %% [markdown]
# ### MULTIPLE IS (capacity = 50), all-normalized

# %%
files = {delta : glob.glob(path + '*env=RLLAB.ACROBOT*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta) for delta in deltas}
candidates_MIS50 = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_MIS50, bootstrap=True, roll=10)
# Out:
# delta=0.8000: -884.596501 ± 309.835006	[-1269.307473, -499.885529]	 total horizon: 4995500
# delta=0.6000: -778.488606 ± 340.278778	[-1201.000514, -355.976698]	 total horizon: 4995500
# delta=0.4000: -1000.096622 ± 220.439500	[-1273.808413, -726.384831]	 total horizon: 4995500
# delta=0.2000: -860.418629 ± 258.434481	[-1181.307420, -539.529837]	 total horizon: 4995500
# delta=0.1000: -753.968007 ± 251.456040	[-1066.191918, -441.744095]	 total horizon: 4995500
# delta=0.0500: -644.602664 ± 157.374065	[-840.008375, -449.196953]	 total horizon: 4995500
# delta=0.0100: -782.853191 ± 98.153723	[-904.727135, -660.979246]	 total horizon: 4995500
# delta=0.0050: -930.705142 ± 221.231773	[-1205.400670, -656.009614]	 total horizon: 4995500
# delta=0.0010: -1143.040631 ± 13.363667	[-1159.633815, -1126.447446]	 total horizon: 4995500

# %% [markdown]
# ### SINGLE vs MULTI

# %%
f = nu.compare({'single (delta = 0.6)' : candidates_IS['delta=0.6000'], 
                'multi (capacity=10, delta = 0.01)': candidates_MIS10['delta=0.0100'], 
                'multi (capacity=50, delta = 0.05)': candidates_MIS50['delta=0.0500']},
              bootstrap=True, roll=10)
# Out:
# single (delta = 0.6): -1432.097278 ± 4.880514	[-1438.157237, -1426.037319]	 total horizon: 4995500
# multi (capacity=10, delta = 0.01): -668.036356 ± 66.810392	[-750.992414, -585.080297]	 total horizon: 4995500
# multi (capacity=50, delta = 0.05): -644.602664 ± 157.374065	[-840.008375, -449.196953]	 total horizon: 4995500

# %% [markdown]
# ### Single with batchsize = 10

# %%
files = {delta : glob.glob(path + '*env=RLLAB.ACROBOT*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta) for delta in deltas}
candidates_BATCH = {'delta=%.4f' % delta : [nu.read_data(logfile) for logfile in files[delta]] for delta in deltas}
f = nu.compare(candidates_BATCH, bootstrap=True)
# Out:
# delta=0.8000: -658.501151 ± 285.328016	[-1012.782676, -304.219626]	 total horizon: 500000
# delta=0.6000: -473.427071 ± 112.560865	[-613.189844, -333.664297]	 total horizon: 500000
# delta=0.4000: -595.890356 ± 28.020433	[-630.682319, -561.098393]	 total horizon: 500000
# delta=0.2000: -515.084908 ± 75.207912	[-608.467865, -421.701951]	 total horizon: 500000
# delta=0.1000: -528.773271 ± 64.182603	[-608.466499, -449.080044]	 total horizon: 500000
# delta=0.0500: -643.994117 ± 98.557207	[-766.369052, -521.619181]	 total horizon: 500000
# delta=0.0100: -954.612345 ± 90.827751	[-1067.389893, -841.834796]	 total horizon: 500000
# delta=0.0050: -1037.773129 ± 101.545550	[-1163.858582, -911.687676]	 total horizon: 500000
# delta=0.0010: -1154.516710 ± 1.759552	[-1156.701482, -1152.331938]	 total horizon: 500000

# %% [markdown]
# ### 1 x 10 vs 10 x 1

# %%
f = nu.compare({'batchsize=1, capacity=10 (delta = 0.01)': candidates_MIS10['delta=0.0100'],
               'batchsize=10, capacity=1 (delta = 0.6)': candidates_BATCH['delta=0.6000']},
              bootstrap=True, roll=[10, 1])
# Out:
# batchsize=1, capacity=10 (delta = 0.01): -668.036356 ± 66.810392	[-750.992414, -585.080297]	 total horizon: 4995500
# batchsize=10, capacity=1 (delta = 0.6): -473.427071 ± 112.560865	[-613.189844, -333.664297]	 total horizon: 500000
