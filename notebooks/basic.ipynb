# %% [markdown]
# # Bound 7, uncentered return, N(0, 0.01^2) initialization, binary search

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %%
seeds = [10, 109, 904, 160, 570]

# %% [markdown]
# ## Inverted Pendulum

# %%
path = '../results/may5/poisnpe72/inverted_pendulum/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -15.981967 ± 57.152635	[-86.946336, 54.982401]

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Mountain Car

# %%
path = '../results/may5/poisnpe72/mountain_car/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -81.415064 ± 4.881034	[-87.475668, -75.354459]

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Double Inverted Pendulum

# %%
path = '../results/may5/poisnpe72/double_inverted_pendulum/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 1677.744841 ± 1350.331293	[1.087089, 3354.402593]

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')
