# %% [markdown]
# # PB - POMIS (batchsize = 1)

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
import glob
from importlib import reload

# %%
reload(nu)
# Out:
# <module 'baselines.common.notebook_utils' from '/home/matteo/baselines/baselines/common/notebook_utils.py'>

# %%
plt.close('all')

# %%
seeds = [749, 728, 524, 215, 455, 920, 635, 930, 402, 705, 938, 563, 925, 29, 173, 542, 899, 175, 152, 210]

# %%
path = '../results/pbpomis_final/pbpomis_final'

# %% [markdown]
# ## Setting:
# * Batchsize = 1
# * No bias
# * No centering
# * optimized \delta
# * normalize all (when possible)

# %%
conf = 0.95

# %%
bootstrap = True

# %%
resamples=10000

# %% [markdown]
# ****

# %% [markdown]
# ## CARTPOLE

# %% [markdown]
# ### Single IS (cannot be normalized)

# %%
delta = 0.0001
files = glob.glob(path + '*env=RLLAB.CARTPOLE*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta)
IS =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 10)

# %%
delta = 0.0001
files = glob.glob(path + '*env=RLLAB.CARTPOLE*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta)
MIS10 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 50)

# %%
delta = 0.001
files = glob.glob(path + '*env=RLLAB.CARTPOLE*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta)
MIS50 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### SINGLE IS with batchsize = 10

# %%
delta = 0.1
files = glob.glob(path + '*env=RLLAB.CARTPOLE*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta)
BATCH =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### COMPARISON

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', conf=conf, bootstrap=bootstrap, resamples=resamples)
# Out:
# IS: 87.900197 ± 17.248936	[79.827446, 95.972947]	 total horizon: 4907
# MIS (capacity=10): 4641.223552 ± 925.346226	[4208.148187, 5074.298917]	 total horizon: 232589
# MIS (capacity=50): 4612.666342 ± 972.575949	[4157.486787, 5067.845898]	 total horizon: 231170
# IS (batchsize=10): 4820.898045 ± 665.438725	[4509.463135, 5132.332954]	 total horizon: 241563

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', separate=True, opacity=0.3)

# %% [markdown]
# ****

# %% [markdown]
# ## MOUNTAIN CAR

# %% [markdown]
# ### Single IS (cannot be normalized)

# %%
delta = 0.6
files = glob.glob(path + '*env=RLLAB.MOUNTAIN-CAR*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta)
IS =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 10)

# %%
delta = 0.0005
files = glob.glob(path + '*env=RLLAB.MOUNTAIN-CAR*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta)
MIS10 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 50)

# %%
delta = 0.0005
files = glob.glob(path + '*env=RLLAB.MOUNTAIN-CAR*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta)
MIS50 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### SINGLE IS with batchsize = 10

# %%
delta = 0.05
files = glob.glob(path + '*env=RLLAB.MOUNTAIN-CAR*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta)
BATCH =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### COMPARISON

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', conf=conf, bootstrap=bootstrap, resamples=resamples)
# Out:
# IS: -71.178887 ± 2.114299	[-72.168409, -70.189364]	 total horizon: 51177
# MIS (capacity=10): -75.917704 ± 4.266919	[-77.914684, -73.920724]	 total horizon: 53350
# MIS (capacity=50): -77.748325 ± 3.782183	[-79.518441, -75.978209]	 total horizon: 54396
# IS (batchsize=10): -74.942855 ± 3.456829	[-76.560701, -73.325009]	 total horizon: 52749

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', separate=True, opacity=0.3)

# %% [markdown]
# ****

# %% [markdown]
# ## INVERTED PENDULUM

# %% [markdown]
# ### Single IS (cannot be normalized)

# %%
delta = 0.99
files = glob.glob(path + '*env=RLLAB.INVERTED-PENDULUM*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta)
IS =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 10)

# %%
delta = 0.2
files = glob.glob(path + '*env=RLLAB.INVERTED-PENDULUM*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta)
MIS10 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 50)

# %%
delta = 0.1
files = glob.glob(path + '*env=RLLAB.INVERTED-PENDULUM*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta)
MIS50 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### SINGLE IS with batchsize = 10

# %%
delta = 0.1
files = glob.glob(path + '*env=RLLAB.INVERTED-PENDULUM*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta)
BATCH =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### COMPARISON

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', conf=conf, bootstrap=bootstrap, resamples=resamples)
# Out:
# IS: -111.347018 ± 2.078437	[-112.319757, -110.374280]	 total horizon: 11452
# MIS (capacity=10): -97.153978 ± 16.777120	[-105.005912, -89.302044]	 total horizon: 31274
# MIS (capacity=50): -70.621673 ± 35.392583	[-87.185912, -54.057434]	 total horizon: 83274
# IS (batchsize=10): -24.467689 ± 69.873848	[-57.169657, 8.234278]	 total horizon: 116523

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', separate=True, opacity=0.3)

# %% [markdown]
# ****

# %% [markdown]
# ## DOUBLE INVERTED PENDULUM

# %% [markdown]
# ### Single IS (cannot be normalized)

# %%
delta = 0.001
files = glob.glob(path + '*env=RLLAB.INVERTED-DOUBLE-PENDULUM*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta)
IS =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 10)

# %%
delta = 0.001
files = glob.glob(path + '*env=RLLAB.INVERTED-DOUBLE-PENDULUM*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta)
MIS10 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 50)

# %%
delta = 0.0005
files = glob.glob(path + '*env=RLLAB.INVERTED-DOUBLE-PENDULUM*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta)
MIS50 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### SINGLE IS with batchsize = 10

# %%
delta = 0.05
files = glob.glob(path + '*env=RLLAB.INVERTED-DOUBLE-PENDULUM*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta)
BATCH =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### COMPARISON

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', conf=conf, bootstrap=bootstrap, resamples=resamples)
# Out:
# IS: 146.547126 ± 4.446968	[144.465881, 148.628371]	 total horizon: 8016
# MIS (capacity=10): 2575.862551 ± 1532.689041	[1858.541999, 3293.183103]	 total horizon: 139287
# MIS (capacity=50): 3313.328690 ± 1251.126348	[2727.783535, 3898.873845]	 total horizon: 178724
# IS (batchsize=10): 1623.601911 ± 1304.154163	[1013.238975, 2233.964848]	 total horizon: 87956

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', separate=True, opacity=0.3)

# %% [markdown]
# ****

# %% [markdown]
# ## ACROBOT

# %% [markdown]
# ### Single IS (cannot be normalized)

# %%
delta = 0.99
files = glob.glob(path + '*env=RLLAB.ACROBOT*norm=none*batchsize=1_*cap=1_*delta=%.4f*' % delta)
IS =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 10)

# %%
delta = 0.01
files = glob.glob(path + '*env=RLLAB.ACROBOT*norm=all*batchsize=1_*cap=10_*delta=%.4f*' % delta)
MIS10 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### MULTIPLE IS (capacity = 50)

# %%
delta = 0.05
files = glob.glob(path + '*env=RLLAB.ACROBOT*norm=all*batchsize=1_*cap=50_*delta=%.4f*' % delta)
MIS50 =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### SINGLE IS with batchsize = 10

# %%
delta = 0.6
files = glob.glob(path + '*env=RLLAB.ACROBOT*norm=all*batchsize=10_*cap=1_*delta=%.4f*' % delta)
BATCH =  [nu.read_data(logfile) for logfile in files]

# %% [markdown]
# ### COMPARISON

# %%
f = nu.compare({'IS' : IS, 
                'MIS (capacity=10)' : MIS10,
                'MIS (capacity=50)' : MIS50, 
                'IS (batchsize=10)' : BATCH}, key='WindowRewMean', separate=True, opacity=0.3)
