# %% [markdown]
# # Bound 7, linear policy w/out bias, uncentered return, N(0, 0.01^2) initialization, binary search, adabatch2

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %%
seeds = [10, 109, 904, 160, 570]

# %% [markdown]
# ## Cartpole

# %%
path = '../results/may5/poisnpe72/cartpole/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 4926.787526 ± 63.211536	[4848.300038, 5005.275014]	 total horizon: 246354

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Inverted Pendulum

# %%
path = '../results/may5/poisnpe72/inverted_pendulum/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 0.943349 ± 68.511551	[-84.124978, 86.011675]	 total horizon: 148551

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Mountain Car

# %%
path = '../results/may5/poisnpe72/mountain_car/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -80.864271 ± 4.911041	[-86.962134, -74.766408]	 total horizon: 56255

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Acrobot

# %%
path = '../results/may5/poisnpe72/acrobot/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -463.882428 ± 50.359504	[-526.412012, -401.352845]	 total horizon: 250000

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Double Inverted Pendulum

# %%
path = '../results/may5/poisnpe72/double_inverted_pendulum/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 1763.383828 ± 1427.807241	[-9.473020, 3536.240675]	 total horizon: 95340

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Swimmer

# %%
path = '../results/may5/poisnpe72/swimmer/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 86.037146 ± 0.724494	[85.137568, 86.936725]	 total horizon: 250000

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Hopper

# %%
path = '../results/may5/poisnpe72/hopper/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 50.035116 ± 13.449257	[33.335658, 66.734574]	 total horizon: 25319

# %%
nu.plot_all(runs)

# %%
plt.close('all')
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## 2D Walker

# %%
path = '../results/may5/poisnpe72/walker2d/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 0.667442 ± 2.054184	[-1.883165, 3.218049]	 total horizon: 31392

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Half-Cheetah

# %%
path = '../results/may5/poisnpe72/half_cheetah/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 163.563858 ± 100.074778	[39.304609, 287.823108]	 total horizon: 250000

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Ant

# %%
path = '../results/may5/poisnpe72/ant/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 4.260527 ± 0.313321	[3.871488, 4.649566]	 total horizon: 25350

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Simple humanoid

# %%
path = '../results/may5/poisnpe72/simple_humanoid/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 24.947730 ± 0.324790	[24.544449, 25.351010]	 total horizon: 53456

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')
