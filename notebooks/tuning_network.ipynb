# %% [markdown]
# # POIS(NPE) + NN

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %%
seeds = [10, 109]

# %% [markdown]
# ## Cartpole

# %%
deltas = ['08']
path = '../results/tuning_network/delta_%s/multipoisnpe/bound_6/cartpole_rllab/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed), scale='Samples')
                                           for seed in seeds] for delta in deltas}
nu.compare(candidates, scale='Samples', ylim=[-500,5500])
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1903: RuntimeWarning: invalid value encountered in greater
#   cond0 = self._argcheck(*args) & (scale > 0) & (loc == loc)

# %%
deltas = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning_network/delta_%s/multipoisnpe/bound_6/cartpole_rllab/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed), scale='Samples')
                                           for seed in seeds] for delta in deltas}
nu.compare(candidates, scale='Samples', ylim=[-500,5500])
# Out:
# /home/matteo/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1903: RuntimeWarning: invalid value encountered in greater
#   cond0 = self._argcheck(*args) & (scale > 0) & (loc == loc)

# %% [markdown]
# ### delta = 0.8, no subsampling

# %%
seeds = [10]

# %%
path = '../results/multipoisnpe/multipoisnpe/bound6/cartpole_rllab/seed_%d/progress.csv'
runs = [nu.read_data(path % seed, scale='Samples') for seed in seeds]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ab1e3a7d6e3a> in <module>()
#       1 path = '../results/multipoisnpe/multipoisnpe/bound6/cartpole_rllab/seed_%d/progress.csv'
# ----> 2 runs = [nu.read_data(path % seed, scale='Samples') for seed in seeds]
#
# <ipython-input-5-ab1e3a7d6e3a> in <listcomp>(.0)
#       1 path = '../results/multipoisnpe/multipoisnpe/bound6/cartpole_rllab/seed_%d/progress.csv'
# ----> 2 runs = [nu.read_data(path % seed, scale='Samples') for seed in seeds]
#
# ~/baselines/baselines/common/notebook_utils.py in read_data(path, iters, default_batchsize, scale)
#      14
#      15 def read_data(path, iters=None, default_batchsize=100, scale='Eps'):
# ---> 16     df = pd.read_csv(path, encoding='utf-8')
#      17     if iters: df = df.loc[:iters, :]
#      18     if not 'BatchSize' in df: df['BatchSize'] = default_batchsize
#
# ...
