# %% [markdown]
# # POIS(NPE) + NN

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %%
seeds = [10, 109]

# %% [markdown]
# ## Cartpole

# %%
deltas = ['01', '02', '03','04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning_network/delta_%s/multipoisnpe/bound_6/cartpole_rllab/seed_%d/progress.csv'
#runs = [nu.read_data(path % (delta)) for delta in deltas]
candidates = {delta[0] + '.' + delta[1] : [nu.read_data2(path % (delta,seed)) for seed in seeds] for delta in deltas}
nu.compare(candidates, conf=0.)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EpsSoFar'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-c35a2e8a396c> in <module>()
# ...

# %% [markdown]
# ## LQG

# %%
deltas = ['01', '02', '03','04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning/adapoisnpe_linear/delta_%s/lqg/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed)) for seed in seeds] for delta in deltas}
nu.compare(candidates, xlim=[0,1000], ylim=[-1000,100])
