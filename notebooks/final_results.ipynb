# %% [markdown]
# # Final Results

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %% [markdown]
# ## PB-POIS (Linear Policy)

# %%
seeds = [10, 109, 904, 160, 570, 662, 963, 100, 746, 236, 247, 689, 153, 947, 307, 42, 950, 315, 545, 178]

# %% [markdown]
# ## LQG

# %% [markdown]
# * \delta = 0.9

# %%
path = '../results/final/poisnpe_linear/lqg/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -30.298586 ± 2.296536	[-31.373398, -29.223774]	 total horizon: 20000

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Cartpole

# %% [markdown]
# * \delta = 0.4

# %%
path = '../results/final/poisnpe_linear/cartpole/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 4942.838579 ± 43.511128	[4922.474744, 4963.202414]	 total horizon: 247157

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## Inverted Pendulum

# %% [markdown]
# * \delta = 0.8

# %%
path = '../results/final/poisnpe_linear/inverted_pendulum/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -37.031101 ± 62.029677	[-66.061883, -8.000319]	 total horizon: 113456

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
#    ## Dobule Inverted Pendulum

# %% [markdown]
# * \delta = 0.1

# %%
path = '../results/final/poisnpe_linear/double_inverted_pendulum/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 3871.594815 ± 1086.322700	[3363.180142, 4380.009489]	 total horizon: 208014

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
#    ## Mountain Car

# %% [markdown]
# * \delta = 1.

# %%
path = '../results/final/poisnpe_linear/mountain_car/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -67.027000 ± 4.462152	[-69.115351, -64.938649]	 total horizon: 48081

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
#    ## Acrobot

# %% [markdown]
# * \delta = 0.2

# %%
path = '../results/final/poisnpe_linear/acrobot/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -470.306079 ± 157.570071	[-544.051142, -396.561015]	 total horizon: 250000

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')

# %% [markdown]
# ## POIS(NPE) - MLP(100,50,25) Policy

# %%
seeds = [10, 109, 904, 160, 570]

# %% [markdown]
# ## Cartpole

# %% [markdown]
# * \delta = 0.6

# %%
path = '../results/final/poisnpe_mlp/cartpole/seed_%d/progress.csv'
runs = [nu.read_data(path % seed, scale='Samples') for seed in seeds]

# %%
nu.plot_ci(runs, scale='Samples')

# %%
nu.print_ci(runs)
# Out:
# 4428.144487 ± 138.636159	[4256.004960, 4600.284015]	 total horizon: 221498

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Mountain Car

# %% [markdown]
# * \delta = 0.3

# %%
path = '../results/final/poisnpe_mlp/mountain_car/seed_%d/progress.csv'
runs = [nu.read_data(path % seed, scale='Samples') for seed in seeds]

# %%
nu.plot_ci(runs, scale='Samples')

# %%
nu.print_ci(runs)
# Out:
# -78.912423 ± 2.548499	[-82.076802, -75.748044]	 total horizon: 54540

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Swimmer

# %% [markdown]
# * \delta = 0.6

# %%
path = '../results/final/poisnpe_mlp/swimmer/seed_%d/progress.csv'
runs = [nu.read_data(path % seed, scale='Samples') for seed in seeds]

# %%
nu.plot_ci(runs, scale='Samples')

# %%
nu.print_ci(runs)
# Out:
# 76.778747 ± 1.625542	[74.760370, 78.797123]	 total horizon: 250000

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Double Inverted Pendulum

# %% [markdown]
# * \delta = 0.8

# %%
path = '../results/final/poisnpe_mlp/double_inverted_pendulum/seed_%d/progress.csv'
runs = [nu.read_data(path % seed, scale='Samples') for seed in seeds]

# %%
nu.plot_ci(runs, scale='Samples')

# %%
nu.print_ci(runs)
# Out:
# 3161.366772 ± 959.205622	[1970.355684, 4352.377860]	 total horizon: 170446

# %%
nu.plot_all(runs)
