# %% [markdown]
# # Bound 7, linear policy w/out bias, uncentered return, N(0, 0.01^2) initialization, binary search, adabatch2

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %%
seeds = [10, 109, 904, 160, 570, 662, 963, 100, 746, 236, 247, 689, 153, 947, 307, 42, 950, 315, 545, 178]

# %% [markdown]
# ## Cartpole

# %%
path = '../results/may11/poisnpe/cartpole/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 4942.838579 ± 43.511128	[4922.474744, 4963.202414]	 total horizon: 247157

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')
