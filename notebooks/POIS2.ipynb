# %% [markdown]
# # POIS2 results check

# %%
import sys
sys.path.remove('/Users/nicom/Documents/Projects/openai/baselines')
sys.path.insert(0, '/Users/nicom/Documents/Projects/t3p/baselines')
print(sys.path)
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob
# Out:
# ['/Users/nicom/Documents/Projects/t3p/baselines', '', '/Users/nicom/Documents/Projects/t3p/baselines/notebooks', '/Users/nicom/anaconda/lib/python36.zip', '/Users/nicom/anaconda/lib/python3.6', '/Users/nicom/anaconda/lib/python3.6/lib-dynload', '/Users/nicom/.local/lib/python3.6/site-packages', '/Users/nicom/anaconda/lib/python3.6/site-packages', '/Users/nicom/anaconda/lib/python3.6/site-packages/aeosa', '/Users/nicom/anaconda/lib/python3.6/site-packages/pgmpy-0.1.3-py3.6.egg', '/Users/nicom/Documents/Projects/multigridworld', '/Users/nicom/Documents/Projects/sneks', '/Users/nicom/Documents/Projects/duckietown/gym-duckietown', '/Users/nicom/anaconda/lib/python3.6/site-packages/IPython/extensions', '/Users/nicom/.ipython']

# %%
path1 = '../timed_logs/swimmer_pois1_njobs10_nn.csv'
path2 = '../timed_logs/swimmer_pois2_njobs10_nn.csv'
d1 = pd.read_csv(path1)
d2 = pd.read_csv(path2)

# %%
plt.plot(d1['Ep'])
# Out:
#      EpRewMean  Itaration      ESSRenyi     MinIWNorm      MaxIWNorm  \
# 0    -0.351591          1  1.120525e-03  1.560369e-08      29.420424
# 1     0.535487          2  2.133773e-05  1.947447e-09     343.596530
# 2     1.020012          3  4.906166e-05  2.346954e-09     592.795000
# 3     2.404499          4  6.767098e-05  4.935434e-09     105.481240
# 4     1.930663          5  5.047837e-04  2.650034e-09      83.692696
# 5     2.675641          6  9.411973e-08  2.066769e-13    4102.009000
# 6     3.702169          7  4.065784e+00  3.017775e-06       0.350299
# 7     4.475034          8  1.489292e-08  3.153465e-14    9281.403000
# 8     4.879498          9  1.490158e-02  2.122626e-08      70.497020
# 9     4.848914         10  1.053445e-01  4.137846e-08      10.859014
# 10    5.635257         11  1.393541e-02  6.016315e-07     103.036700
# 11    4.833406         12  4.825940e-05  6.841870e-10     362.727200
# 12    5.783202         13  1.012268e-05  3.825158e-09     409.254640
# ...
