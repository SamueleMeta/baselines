# %% [markdown]
# # Bound 7, uncentered return, N(0, 0.01^2) initialization, binary search

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %%
seeds = [10, 109, 904, 160,
570, 662, 963, 100,
746, 236, 247, 689,
153, 947, 307, 42,
950, 315, 545, 178, 
892, 756, 376, 203,
173, 599, 550, 647,
624, 563,  88, 188,
140, 266, 806, 170,
819, 393, 646, 784]

# %% [markdown]
# ## LQG

# %%
path = '../results/maythefirst/poisnpe/bound_7/lqg/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs, ylim=[-30, 0])

# %%
nu.print_ci(runs)
# Out:
# -30.520016	[-31.204557, -29.835475]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Cartpole (rllab): linear policy

# %%
path = '../results/maythefirst/poisnpe/bound_7/cartpole_rllab/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 3809.207620	[3288.677263, 4329.737978]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Swimmer

# %%
path = '../results/maythefirst/poisnpe/bound_7/swimmer/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 76.511163	[71.863617, 81.158709]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## LQG 10 off iters

# %%
seeds = [10, 109, 904, 160, 570, 662, 963, 100, 746, 236]
path = '../results/fixedbatch/poisnpe/bound_7/lqg/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -31.556926	[-33.001147, -30.112706]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## LQG Adbatch1 (10 off iters)

# %%
seeds = [10, 109, 904, 160, 570, 662, 963, 100, 746, 236]
path = '../results/adabatch1/poisnpe/bound_7/lqg/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -13.140682	[-13.442327, -12.839038]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## LQG Adbatch2 (10 off iters)

# %%
seeds = [10, 904, 160, 570, 662, 963, 100, 746, 236]
path = '../results/adabatch2/poisnpe/bound_7/lqg/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# -13.861050	[-14.705515, -13.016585]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Cartpole 10 off iterations

# %%
seeds = [10, 904, 160, 570, 662, 963, 100, 746, 236]
path = '../results/fixedbatch/poisnpe/bound_7/cartpole_rllab/seed_%d/progress.csv'
runs = [nu.read_data(path % seed, iters=200) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 4287.799045	[3418.958610, 5156.639481]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Cartpole adabatch1 (10 off iterations)

# %%
seeds = [10, 904, 570, 963, 746]
path = '../results/adabatch1_temp/poisnpe/bound_7/cartpole_rllab/seed_%d/progress.csv'
runs = [nu.read_data(path % seed, iters=200) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 4627.456906	[3645.638936, 5609.274876]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Cartpole adabatch2 (10 off iterations)

# %%
seeds = [10, 109, 904, 160, 570, 662, 963, 100, 746, 236]
path = '../results/adabatch2_temp/poisnpe/bound_7/cartpole_rllab/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs)

# %%
nu.print_ci(runs)
# Out:
# 4953.964572	[4945.198156, 4962.730989]

# %%
nu.plot_all(runs)

# %%
nu.plot_all(runs, key='BatchSize')
