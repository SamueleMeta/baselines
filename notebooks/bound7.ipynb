# %% [markdown]
# # Bound 7, uncentered return, N(0, 0.01^2) initialization, binary search

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %%
seeds = [10, 109, 904, 160, 570, 662, 963, 100, 746, 236]

# %% [markdown]
# ## LQG

# %%
path = '../results/fixedbatch/poisnpe/bound_7/lqg/seed_%d/progress.csv'
runs = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs, ylim=[-30, 0])

# %%
nu.print_ci(runs)
# Out:
# -31.556926	[-33.001147, -30.112706]

# %%
nu.plot_all(runs)

# %% [markdown]
# ## Cartpole (rllab): linear policy, 10 off iters

# %% [markdown]
# ### Fixed batch size

# %%
path = '../results/fixedbatch/poisnpe/bound_7/cartpole_rllab/seed_%d/progress.csv'
runs0 = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs0)

# %%
nu.print_ci(runs0)
# Out:
# 4351.207370	[3575.491878, 5126.922861]

# %%
nu.plot_all(runs0)

# %% [markdown]
# ### Adaptive batch size (1)

# %%
path = '../results/adabatch1/poisnpe/bound_7/cartpole_rllab/seed_%d/progress.csv'
runs1 = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs1)

# %%
nu.print_ci(runs1)
# Out:
# 4284.725858	[3501.076436, 5068.375281]

# %%
nu.plot_all(runs1)

# %%
nu.plot_all(runs1, key='BatchSize')

# %% [markdown]
# ### Adaptive batch size (1 + backtracking)

# %%
path = '../results/adabatch1_backtrack/poisnpe/bound_7/cartpole_rllab/seed_%d/progress.csv'
runs3 = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs3)

# %%
nu.print_ci(runs3)
# Out:
# 4430.248730	[3679.925620, 5180.571839]

# %%
nu.plot_all(runs3)

# %%
nu.plot_all(runs3, key='BatchSize')

# %% [markdown]
# ### Adaptive batch size (2)

# %%
path = '../results/adabatch2/poisnpe/bound_7/cartpole_rllab/seed_%d/progress.csv'
runs2 = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs2)

# %%
nu.print_ci(runs2)
# Out:
# 4768.614516	[4669.237296, 4867.991737]

# %%
nu.plot_all(runs2)

# %%
nu.plot_all(runs2, key='BatchSize')

# %%
trpo_paths = glob.glob("../../pois-nips2018/data_new/cartpole/CARTPOLE_TRPO*.csv")
runstrpo = [nu.read_data(p, iters=500).drop('Weights', 1) for p in trpo_paths]

# %%
nu.compare({'fixed':runs0, 'ada1':runs1, 'ada1+bt':runs3, 'ada2':runs2, 'trpo':runstrpo})

# %% [markdown]
# ## Swimmer

# %%
path = '../results/maythefirst/poisnpe/bound_7/swimmer/seed_%d/progress.csv'
runs0 = [nu.read_data(path % seed) for seed in seeds]

# %%
nu.plot_ci(runs0)

# %%
nu.print_ci(runs0)
# Out:
# 80.647652	[72.795796, 88.499507]

# %%
nu.plot_all(runs0)

# %%
path = '../results/adabatch2/poisnpe/bound_7/swimmer/seed_%d/progress.csv'
runs2 = [nu.read_data(path % seed) for seed in seeds]
nu.compare({'fixed':runs0, 'ada2':runs2}, ylim=[80,100])

# %%
nu.plot_all(runs2)

# %%
nu.plot_all(runs2, key='BatchSize')
