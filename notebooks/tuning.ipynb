# %% [markdown]
# # Bound 7, linear policy w/out bias, uncentered return, N(0, 0.01^2) initialization, binary search, adabatch2

# %%
import baselines.common.notebook_utils as nu
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
reload(nu)
import glob

# %%
plt.close('all')

# %%
seeds = [10, 109, 904, 160, 570]

# %% [markdown]
# ## Cartpole

# %%
deltas = ['01', '02', '03','04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning/adapoisnpe_linear/delta_%s/cartpole/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed)) for seed in seeds] for delta in deltas}
nu.compare(candidates, ylim=[0, 6000], xlim=[0,10000])

# %% [markdown]
# ## LQG

# %%
deltas = ['01', '02', '03','04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning/adapoisnpe_linear/delta_%s/lqg/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed)) for seed in seeds] for delta in deltas}
nu.compare(candidates, xlim=[0,1000], ylim=[-1000,100])

# %% [markdown]
# ## Double Inverted Pendulum

# %%
deltas = ['01', '02', '03','04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning/delta_%s/adapoisnpe/double_inverted_pendulum/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed)) for seed in seeds] for delta in deltas}
nu.compare(candidates)

# %% [markdown]
# ## Inverted Pendulum

# %%
deltas = ['01', '02', '03','04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning/delta_%s/adapoisnpe/inverted_pendulum/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed)) for seed in seeds] for delta in deltas}
nu.compare(candidates)

# %% [markdown]
# ## Acrobot

# %%
deltas = ['01', '02', '03','04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning/delta_%s/adapoisnpe/acrobot/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed)) for seed in seeds] for delta in deltas}
nu.compare(candidates, ylim=[-1000,-100])

# %% [markdown]
# ## Mountain Car

# %%
deltas = ['01', '02', '03','04', '05', '06', '07', '08', '09', '10']
path = '../results/tuning/delta_%s/adapoisnpe/mountain_car/seed_%d/progress.csv'
candidates = {delta[0] + '.' + delta[1] : [nu.read_data(path % (delta,seed)) for seed in seeds] for delta in deltas}
nu.compare(candidates, ylim=[-200,0])
